# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseTNRoberts/AAAI-paper-2023/blob/main/pop_analysis_dropout_sweep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nbformat --upgrade
# !pip install seaborn
# !pip install researchpy

# %%
# Assuming your CSV file is named "data.csv"
import pandas as pd
import tqdm

import pandas as pd
import plotly.graph_objects as go
import researchpy as rp
import numpy as np
import ast

from google.colab import drive
drive.mount('/content/drive')

loc = "/content/drive/MyDrive/Data/results/rosch1975_alternate_popLM_50/"
# Out:
# Mounted at /content/drive

# %%
models = ['gpt2_dropout_0.1', 'gpt2_dropout_0.2', 'gpt2_dropout_0.3', 'gpt2_dropout_0.4',
          'gpt2_dropout_0.5', 'gpt2_dropout_0.6', 'gpt2_dropout_0.7', 'gpt2_dropout_0.8']

# for sum
#select_reduction = 0
# for mean
select_reduction = 1

full_range = np.arange(0.1,0.9,0.1)
short_range = full_range

temp = pd.read_csv(loc+models[0]+".csv")
temp[str(short_range[0])] = temp['score (sum, mean, [list)'].apply(ast.literal_eval)
temp[str(short_range[0])] = [[t[select_reduction] for t in m] for m in temp[str(short_range[0])]]
temp = temp.drop(columns=['score (sum, mean, [list)'])
data = temp.copy()

short_range = short_range[1:]

for index, model in enumerate(models[1:]):

  temp = pd.read_csv(loc+model+".csv")
  temp[str(short_range[index])] = temp['score (sum, mean, [list)'].apply(ast.literal_eval)
  temp[str(short_range[index])] = [[t[select_reduction] for t in m] for m in temp[str(short_range[index])]]
  temp = temp.drop(columns=['score (sum, mean, [list)'])
  data = pd.merge(data, temp[['category','item', str(short_range[index])]])



data
# Out:
#                    preamble stimulus             item category  rank  \
# 0               A doll is a     toy.             doll      toy     1
# 1                A top is a     toy.              top      toy     2
# 2    A jack-in-the-box is a     toy.  jack-in-the-box      toy     3
# 3        A toy soldier is a     toy.      toy soldier      toy     4
# 4              A yo-yo is a     toy.            yo-yo      toy     5
# ..                      ...      ...              ...      ...   ...
# 560             A foot is a  weapon.             foot   weapon    56
# 561              A car is a  weapon.              car   weapon    57
# 562      A screwdriver is a  weapon.      screwdriver   weapon    58
# 563              Glass is a  weapon.            glass   weapon    59
# 564             A shoe is a  weapon.             shoe   weapon    60
#
#         params model                                                0.1  \
# ...

# %%
def cohend(d1, d2) -> float:
  # calculate the size of samples
  n1, n2 = len(d1), len(d2)

  # calculate the variance of the samples
  s1, s2 = np.var(d1, ddof=1), np.var(d2, ddof=1)

  # calculate the pooled standard deviation
  s = np.sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))

  # calculate the means of the samples
  u1, u2 = np.mean(d1), np.mean(d2)

  # return the effect size
  return (u1 - u2) / s


df = data

for item in full_range:
  df['mean ' + str(item)] = df.apply(
      lambda row: np.mean(row[str(item)]),
      axis=1)

  df['std ' + str(item)] = df.apply(
      lambda row: np.std(row[str(item)]),
      axis=1)

for index, item in enumerate(full_range[1:]):
  df['delta mean ' + str(full_range[index+1])] = df.apply(
      lambda row: np.mean([a_i - b_i
                           for a_i, b_i in
                           zip(row[str(full_range[index+1])], row[str(full_range[index])])]),
      axis=1)

  df['delta std ' + str(full_range[index+1])] = df.apply(
      lambda row: np.std([a_i - b_i
                           for a_i, b_i in
                           zip(row[str(full_range[index+1])], row[str(full_range[index])])]),
      axis=1)


df
# Out:
#                    preamble stimulus             item category  rank  \
# 0               A doll is a     toy.             doll      toy     1
# 1                A top is a     toy.              top      toy     2
# 2    A jack-in-the-box is a     toy.  jack-in-the-box      toy     3
# 3        A toy soldier is a     toy.      toy soldier      toy     4
# 4              A yo-yo is a     toy.            yo-yo      toy     5
# ..                      ...      ...              ...      ...   ...
# 560             A foot is a  weapon.             foot   weapon    56
# 561              A car is a  weapon.              car   weapon    57
# 562      A screwdriver is a  weapon.      screwdriver   weapon    58
# 563              Glass is a  weapon.            glass   weapon    59
# 564             A shoe is a  weapon.             shoe   weapon    60
#
#         params model                                                0.1  \
# ...

# %%
import plotly.graph_objects as go

mean_delta = [np.mean(df['delta mean ' + str(item)]) for item in short_range]
std_delta = [np.mean(df['delta std ' + str(item)]) for item in short_range]

trace0 = go.Scatter(
  x=short_range,
  y=mean_delta
)
trace1 = go.Scatter(
  x=short_range,
  y=std_delta
)

fig = go.Figure([trace0, trace1])
fig.update_layout(title='mean change in mean, std vs dropout rate')
fig.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# look to see if typicality effects how mean and std grow with dropout

this = set(df['rank'])

ranks = list(this)
means={}
stds={}

mean_probs={}
mean_stds={}

for rank in this:
  group = df[df['rank']==rank]
  means[rank] = [np.mean(group['delta mean ' + str(item)]) for item in short_range]
  stds[rank] = [np.mean(group['delta std ' + str(item)]) for item in short_range]
  mean_probs[rank] = [np.mean(group['mean ' + str(item)]) for item in short_range]
  mean_stds[rank] = [np.mean(group['std ' + str(item)]) for item in short_range]

print(means)

plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=means[rank],
    name= str(rank)
  ))

fig = go.Figure(plots)
fig.update_layout(title='mean change in probability vs dropout rate (by typicality)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=stds[rank],
    name= str(rank)
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='mean change in std vs dropout rate (by typicality)')
fig1.show(renderer='colab')
# Out:
# {1: [-0.10975439643859863, -0.2857688717842102, -1.0102467274665832, -1.2314759445190429, -1.0382274742126465, -0.9761454753875732, -1.0495386981964112], 2: [0.07043768692016603, -0.11560490131378173, -0.9359234676361086, -1.3787247972488403, -0.9669641485214235, -0.853478669166565, -0.9166898603439331], 3: [-0.05027545928955078, -0.14045698070526122, -1.2337940845489501, -1.4001448240280152, -1.100874607086182, -0.608207721710205, -0.977310064315796], 4: [0.07848915863037108, 0.024122304916381836, -0.8807255630493165, -1.4681255445480346, -1.0526651668548583, -0.7894904956817628, -1.0885164546966553], 5: [0.066369873046875, -0.14155253410339358, -0.7863056983947754, -1.3803616695404053, -0.8212416734695435, -0.7598612670898438, -1.264733247756958], 6: [0.020683368682861338, -0.1087254753112793, -0.7756309356689455, -1.1788687229156494, -1.0333069162368775, -0.8245455961227417, -0.9423420181274412], 7: [-0.0008645439147949227, -0.25211049652099604, -0.8762070150375365, -1.22976391887
# ...

# %%
# look to see if typicality effects mean and std with dropout

plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=mean_probs[rank],
    name= str(rank)
  ))

fig = go.Figure(plots)
fig.update_layout(title='mean probability vs dropout rate (by typicality)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=mean_stds[rank],
    name= str(rank)
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='mean std vs dropout rate (by typicality)')
fig1.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# look to see if category effects how mean and std grow with dropout

this = set(df['category'])

ranks = list(this)
means={}
stds={}

mean_probs={}
mean_stds={}

for rank in this:
  group = df[df['category']==rank]
  means[rank] = [np.mean(group['delta mean ' + str(item)]) for item in short_range]
  stds[rank] = [np.mean(group['delta std ' + str(item)]) for item in short_range]
  mean_probs[rank] = [np.mean(group['mean ' + str(item)]) for item in short_range]
  mean_stds[rank] = [np.mean(group['std ' + str(item)]) for item in short_range]

print(means)

plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=means[rank],
    name= str(rank)
  ))

fig = go.Figure(plots)
fig.update_layout(title='mean change in probability vs dropout rate (by category)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=stds[rank],
    name= str(rank)
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='mean change in std vs dropout rate (by category)')
fig1.show(renderer='colab')
# Out:
# {'furniture': [-0.04658700291315714, -0.34275171073277794, -1.3596709119478863, -1.1523382530212405, -0.7973783121109008, -0.7645901657740276, -1.112252573331197], 'sport': [-0.0789779868368375, -0.16140623755374198, -0.823376008373196, -1.1169857990135579, -0.7579229626413119, -0.6966024589538574, -0.896515341289973], 'toy': [0.009982631365458171, -0.08583235756556193, -0.740216014703115, -1.2633909950256348, -0.944641956647237, -0.8058029780387879, -1.040631162325541], 'tool': [0.08066757678985595, 0.020389219125111897, -0.7449689769744873, -1.3246790625254314, -1.0055522858301797, -0.8088356324831645, -0.8509030087788899], 'vehicle': [0.10858480453491211, -0.05109864044189453, -0.8095983148574828, -1.2777575826644894, -0.974567447090149, -0.8027802654266357, -1.0427133584976196], 'weapon': [-0.001112772623697919, -0.13608419696489968, -0.8263726710478464, -1.4214466360410056, -0.9815998768806456, -0.8959033705393474, -1.0382200071016947], 'clothing': [-0.02158398784290661, 0.02474
# ...

# %%
plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=mean_probs[rank],
    name= str(rank)
  ))

fig = go.Figure(plots)
fig.update_layout(title='mean probability vs dropout rate (by category)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=short_range,
    y=mean_stds[rank],
    name= str(rank)
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='mean std vs dropout rate (by category)')
fig1.show(renderer='colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# How do rank and std correlate as the dropout rate changes?
import researchpy as rp

test = 'pearson'
corr_r_typicality_vs_dropout = []
corr_p_typicality_vs_dropout = []

for item in full_range:
  i,r,p = rp.correlation.corr_case(df[['rank', 'std ' + str(item)]], method = test)
  print(r,p)
  print('------')
  corr_r_typicality_vs_dropout.append(r['rank'][1])
  corr_p_typicality_vs_dropout.append(p['rank'][1])

plots = []
plots.append(go.Scatter(
    x=full_range,
    y=corr_r_typicality_vs_dropout,
    name= 'coeficient (r)'
  ))

plots.append(go.Scatter(
    x=full_range,
    y=corr_p_typicality_vs_dropout,
    name= 'significance (p)'
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='correlation (typicality-std probability) vs dropout')
fig1.show(renderer='colab')
# Out:
#            rank std 0.1
# rank        1.0 -0.1759
# std 0.1 -0.1759     1.0            rank std 0.1
# rank     0.0000  0.0000
# std 0.1  0.0000  0.0000
# ------
#            rank std 0.2
# rank        1.0 -0.1674
# std 0.2 -0.1674     1.0            rank std 0.2
# rank     0.0000  0.0001
# std 0.2  0.0001  0.0000
# ------
#                            rank std 0.30000000000000004
# rank                        1.0                 -0.1613
# std 0.30000000000000004 -0.1613                     1.0                            rank std 0.30000000000000004
# rank                     0.0000                  0.0001
# std 0.30000000000000004  0.0001                  0.0000
# ------
#            rank std 0.4
# rank        1.0 -0.1241
# std 0.4 -0.1241     1.0            rank std 0.4
# rank     0.0000  0.0031
# std 0.4  0.0031  0.0000
# ------
#            rank std 0.5
# rank        1.0  0.0325
# std 0.5  0.0325     1.0            rank std 0.5
# rank     0.0000  0.4404
# std 0.5  0.4404  0.0000
# ...

# %%
test = 'pearson'
corr_r_typicality_vs_dropout = []
corr_p_typicality_vs_dropout = []

for item in full_range:
  i,r,p = rp.correlation.corr_case(df[['rank', 'mean ' + str(item)]], method = test)
  print(r,p)
  print('------')
  corr_r_typicality_vs_dropout.append(r['rank'][1])
  corr_p_typicality_vs_dropout.append(p['rank'][1])

plots = []
plots.append(go.Scatter(
    x=full_range,
    y=corr_r_typicality_vs_dropout,
    name= 'coeficient (r)'
  ))

plots.append(go.Scatter(
    x=full_range,
    y=corr_p_typicality_vs_dropout,
    name= 'significance (p)'
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='correlation (typicality-mean probability) vs dropout')
fig1.show(renderer='colab')
# Out:
#           rank mean 0.1
# rank       1.0    -0.16
# mean 0.1 -0.16      1.0             rank mean 0.1
# rank      0.0000   0.0001
# mean 0.1  0.0001   0.0000
# ------
#             rank mean 0.2
# rank         1.0  -0.1697
# mean 0.2 -0.1697      1.0             rank mean 0.2
# rank      0.0000   0.0001
# mean 0.2  0.0001   0.0000
# ------
#                             rank mean 0.30000000000000004
# rank                         1.0                  -0.1691
# mean 0.30000000000000004 -0.1691                      1.0                             rank mean 0.30000000000000004
# rank                      0.0000                   0.0001
# mean 0.30000000000000004  0.0001                   0.0000
# ------
#             rank mean 0.4
# rank         1.0  -0.1549
# mean 0.4 -0.1549      1.0             rank mean 0.4
# rank      0.0000   0.0002
# mean 0.4  0.0002   0.0000
# ------
#             rank mean 0.5
# rank         1.0  -0.1357
# mean 0.5 -0.1357      1.0             rank mean 0.5
# ...

# %%
 # How does the correlation of typicality with mean/std change on a per category basis?

test = 'pearson'

this = set(df['category'])

ranks = list(this)
corrs={}
sigs={}


for rank in this:
  group = df[df['category']==rank]
  corrs[rank] = []
  sigs[rank] = []
  for item in full_range:
    i,r,p = rp.correlation.corr_case(group[['rank', 'mean ' + str(item)]], method = test)
    print(r,p)
    print('------')
    corrs[rank].append(r['rank'][1])
    sigs[rank].append(p['rank'][1])

avg_corr = [np.mean([corrs[rank][index]
            for rank in ranks])
            for index in range(full_range.shape[0])]

avg_sigs = [np.mean([float(sigs[rank][index])
            for rank in ranks])
            for index in range(full_range.shape[0])]

plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=full_range,
    y=corrs[rank],
    name= str(rank)
  ))
plots.append(go.Scatter(
    x=full_range,
    y=avg_corr,
    name= 'mean'
  ))

fig = go.Figure(plots)
fig.update_layout(title='correlation (typicality-mean probability) vs dropout (by category)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=full_range,
    y=sigs[rank],
    name= str(rank)
  ))
plots.append(go.Scatter(
    x=full_range,
    y=avg_sigs,
    name= 'mean'
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='significance (typicality-mean probability) vs dropout (by category)',
                   autotypenumbers='convert types')
fig1.show(renderer='colab')
# Out:
#             rank mean 0.1
# rank         1.0  -0.2783
# mean 0.1 -0.2783      1.0             rank mean 0.1
# rank      0.0000   0.0313
# mean 0.1  0.0313   0.0000
# ------
#             rank mean 0.2
# rank         1.0  -0.3471
# mean 0.2 -0.3471      1.0             rank mean 0.2
# rank      0.0000   0.0066
# mean 0.2  0.0066   0.0000
# ------
#                            rank mean 0.30000000000000004
# rank                        1.0                   -0.343
# mean 0.30000000000000004 -0.343                      1.0                             rank mean 0.30000000000000004
# rank                      0.0000                   0.0073
# mean 0.30000000000000004  0.0073                   0.0000
# ------
#            rank mean 0.4
# rank        1.0   -0.228
# mean 0.4 -0.228      1.0             rank mean 0.4
# rank      0.0000   0.0798
# mean 0.4  0.0798   0.0000
# ------
#             rank mean 0.5
# rank         1.0  -0.1179
# mean 0.5 -0.1179      1.0             rank mean 0.5
# ...

# %%
test = 'pearson'

this = set(df['category'])

ranks = list(this)
corrs={}
sigs={}

for rank in this:
  group = df[df['category']==rank]
  corrs[rank] = []
  sigs[rank] = []
  for item in full_range:
    i,r,p = rp.correlation.corr_case(group[['rank', 'std ' + str(item)]], method = test)
    print(r,p)
    print('------')
    corrs[rank].append(r['rank'][1])
    sigs[rank].append(p['rank'][1])

avg_corr = [np.mean([corrs[rank][index]
            for rank in ranks])
            for index in range(full_range.shape[0])]

avg_sigs = [np.mean([float(sigs[rank][index])
            for rank in ranks])
            for index in range(full_range.shape[0])]

plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=full_range,
    y=corrs[rank],
    name= str(rank)
  ))
plots.append(go.Scatter(
    x=full_range,
    y=avg_corr,
    name= 'mean'
  ))

fig = go.Figure(plots)
fig.update_layout(title='correlation (typicality-std probability) vs dropout (by category)')
fig.show(renderer='colab')


plots = []
for rank in ranks:
  plots.append(go.Scatter(
    x=full_range,
    y=sigs[rank],
    name= str(rank)
  ))
plots.append(go.Scatter(
    x=full_range,
    y=avg_sigs,
    name= 'mean'
  ))

fig1 = go.Figure(plots)
fig1.update_layout(title='significance (typicality-std probability) vs dropout (by category)',
                   autotypenumbers='convert types')
fig1.show(renderer='colab')
# Out:
#            rank std 0.1
# rank        1.0  0.0763
# std 0.1  0.0763     1.0            rank std 0.1
# rank     0.0000  0.5626
# std 0.1  0.5626  0.0000
# ------
#            rank std 0.2
# rank        1.0  0.0966
# std 0.2  0.0966     1.0            rank std 0.2
# rank     0.0000  0.4628
# std 0.2  0.4628  0.0000
# ------
#                           rank std 0.30000000000000004
# rank                       1.0                  -0.191
# std 0.30000000000000004 -0.191                     1.0                            rank std 0.30000000000000004
# rank                     0.0000                  0.1437
# std 0.30000000000000004  0.1437                  0.0000
# ------
#            rank std 0.4
# rank        1.0 -0.3238
# std 0.4 -0.3238     1.0            rank std 0.4
# rank     0.0000  0.0116
# std 0.4  0.0116  0.0000
# ------
#            rank std 0.5
# rank        1.0 -0.0681
# std 0.5 -0.0681     1.0            rank std 0.5
# rank     0.0000  0.6051
# std 0.5  0.6051  0.0000
# ...
